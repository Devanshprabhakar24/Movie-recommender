# %%
import numpy as np
import pandas as pd
import ast

import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import PorterStemmer
from typing import List

# %%
movies = pd.read_csv('TMDB_movie_dataset_v11.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')
movies = movies.merge(credits, on='title')

# %%
movies.head(1)
# Out:
#       id      title  vote_average  vote_count    status release_date  \
# 0  27205  Inception         8.364       34495  Released   2010-07-15
#
#      revenue  runtime  adult                     backdrop_path  ...  \
# 0  825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
#
#                         poster_path                               tagline  \
# 0  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg  Your mind is the scene of the crime.
#
#                                genres  \
# 0  Action, Science Fiction, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
#
#                        production_countries  \
# 0  United Kingdom, United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
#
#                                             keywords movie_id  \
# 0  rescue, mission, dream, airplane, paris, franc...    27205
#
#                                                 cast  \
# 0  [{"cast_id": 1, "character": "Dom Cobb", "cred...
#
#                                                 crew
# 0  [{"credit_id": "56e8462cc3a368408400354c", "de...
#
# [1 rows x 27 columns]

# %%
movies.shape
# Out:
# (16294, 27)

# %%
movies = movies[['id', 'title', 'overview', 'genres', 'keywords', 'tagline', 'cast', 'crew']]

# %%
movies.head(1)
# Out:
#       id      title                                           overview  \
# 0  27205  Inception  Cobb, a skilled thief who commits corporate es...
#
#                                genres  \
# 0  Action, Science Fiction, Adventure
#
#                                             keywords  \
# 0  rescue, mission, dream, airplane, paris, franc...
#
#                                 tagline  \
# 0  Your mind is the scene of the crime.
#
#                                                 cast  \
# 0  [{"cast_id": 1, "character": "Dom Cobb", "cred...
#
#                                                 crew
# 0  [{"credit_id": "56e8462cc3a368408400354c", "de...

# %%
movies['overview'] = movies['overview'].fillna('')
movies['tagline'] = movies['tagline'].fillna('')
movies['genres'] = movies['genres'].fillna('')
movies['keywords'] = movies['keywords'].fillna('')

# %%
movies.head(1)
# Out:
#       id      title                                           overview  \
# 0  27205  Inception  Cobb, a skilled thief who commits corporate es...
#
#                                genres  \
# 0  Action, Science Fiction, Adventure
#
#                                             keywords  \
# 0  rescue, mission, dream, airplane, paris, franc...
#
#                                 tagline  \
# 0  Your mind is the scene of the crime.
#
#                                                 cast  \
# 0  [{"cast_id": 1, "character": "Dom Cobb", "cred...
#
#                                                 crew
# 0  [{"credit_id": "56e8462cc3a368408400354c", "de...

# %%
movies.isnull().sum()
# Out:
# id          0
# title       0
# overview    0
# genres      0
# keywords    0
# tagline     0
# cast        0
# crew        0
# dtype: int64

# %%
#movies.dropna(inplace=True)

# %%
movies.drop_duplicates(subset='title', inplace=True)

# %%
#movies.duplicated().sum()

# %%
movies.head(5)
# Out:
#         id            title  \
# 0    27205        Inception
# 3   157336     Interstellar
# 4      155  The Dark Knight
# 6    19995           Avatar
# 11   24428     The Avengers
#
#                                              overview  \
# 0   Cobb, a skilled thief who commits corporate es...
# 3   The adventures of a group of explorers who mak...
# 4   Batman raises the stakes in his war on crime. ...
# 6   In the 22nd century, a paraplegic Marine is di...
# 11  When an unexpected enemy emerges and threatens...
#
#                                          genres  \
# 0            Action, Science Fiction, Adventure
# 3             Adventure, Drama, Science Fiction
# 4                Drama, Action, Crime, Thriller
# 6   Action, Adventure, Fantasy, Science Fiction
# 11           Science Fiction, Action, Adventure
#
#                                              keywords  \
# 0   rescue, mission, dream, airplane, paris, franc...
# 3   rescue, future, spacecraft, race against time,...
# 4   joker, sadism, chaos, secret identity, crime f...
# 6   future, society, culture clash, space travel, ...
# 11  new york city, superhero, shield, based on com...
#
#                                               tagline  \
# 0                Your mind is the scene of the crime.
# 3   Mankind was born on Earth. It was never meant ...
# 4                   Welcome to a world without rules.
# 6                         Enter the world of Pandora.
# 11                            Some assembly required.
#
#                                                  cast  \
# 0   [{"cast_id": 1, "character": "Dom Cobb", "cred...
# 3   [{"cast_id": 9, "character": "Joseph Cooper", ...
# 4   [{"cast_id": 35, "character": "Bruce Wayne", "...
# 6   [{"cast_id": 242, "character": "Jake Sully", "...
# 11  [{"cast_id": 46, "character": "Tony Stark / Ir...
#
#                                                  crew
# 0   [{"credit_id": "56e8462cc3a368408400354c", "de...
# 3   [{"credit_id": "52fe4bbf9251416c910e4801", "de...
# 4   [{"credit_id": "55a0eb4a925141296b0010f8", "de...
# 6   [{"credit_id": "52fe48009251416c750aca23", "de...
# 11  [{"credit_id": "52fe4495c3a368484e02b1cf", "de...

# %%
movies.iloc[0].genres
# Out:
# 'Action, Science Fiction, Adventure'

# %%
def convert(obj: str) -> List[str]:
    try:
        if isinstance(obj, str) and obj.startswith('['):
            return [item["name"].strip() for item in ast.literal_eval(obj)]
        elif isinstance(obj, str):
            return [s.strip() for s in obj.split(",") if s.strip()]
        return []
    except:
        return []

movies['genres'] = movies['genres'].apply(convert)
movies['keywords'] = movies['keywords'].apply(convert)

# %%
def convert_cast(obj: str) -> List[str]:
    try:
        return [i['name'] for i in ast.literal_eval(obj)[:3]]
    except:
        return []

def get_director(obj: str) -> List[str]:
    try:
        return [i['name'] for i in ast.literal_eval(obj) if i['job'] == 'Director']
    except:
        return []

# %%
movies.head(1)
# Out:
#       id      title                                           overview  \
# 0  27205  Inception  Cobb, a skilled thief who commits corporate es...
#
#                                  genres  \
# 0  [Action, Science Fiction, Adventure]
#
#                                             keywords  \
# 0  [rescue, mission, dream, airplane, paris, fran...
#
#                                 tagline  \
# 0  Your mind is the scene of the crime.
#
#                                                 cast  \
# 0  [{"cast_id": 1, "character": "Dom Cobb", "cred...
#
#                                                 crew
# 0  [{"credit_id": "56e8462cc3a368408400354c", "de...

# %%
movies['cast'] = movies['cast'].apply(convert_cast)
movies['crew'] = movies['crew'].apply(get_director)

# %%
movies.head(5)
# Out:
#         id            title  \
# 0    27205        Inception
# 3   157336     Interstellar
# 4      155  The Dark Knight
# 6    19995           Avatar
# 11   24428     The Avengers
#
#                                              overview  \
# 0   Cobb, a skilled thief who commits corporate es...
# 3   The adventures of a group of explorers who mak...
# 4   Batman raises the stakes in his war on crime. ...
# 6   In the 22nd century, a paraplegic Marine is di...
# 11  When an unexpected enemy emerges and threatens...
#
#                                            genres  \
# 0            [Action, Science Fiction, Adventure]
# 3             [Adventure, Drama, Science Fiction]
# 4                [Drama, Action, Crime, Thriller]
# 6   [Action, Adventure, Fantasy, Science Fiction]
# 11           [Science Fiction, Action, Adventure]
#
#                                              keywords  \
# 0   [rescue, mission, dream, airplane, paris, fran...
# 3   [rescue, future, spacecraft, race against time...
# 4   [joker, sadism, chaos, secret identity, crime ...
# 6   [future, society, culture clash, space travel,...
# 11  [new york city, superhero, shield, based on co...
#
#                                               tagline  \
# 0                Your mind is the scene of the crime.
# 3   Mankind was born on Earth. It was never meant ...
# 4                   Welcome to a world without rules.
# 6                         Enter the world of Pandora.
# 11                            Some assembly required.
#
#                                                  cast                 crew
# 0   [Leonardo DiCaprio, Joseph Gordon-Levitt, Elle...  [Christopher Nolan]
# 3   [Matthew McConaughey, Jessica Chastain, Anne H...  [Christopher Nolan]
# 4       [Christian Bale, Heath Ledger, Aaron Eckhart]  [Christopher Nolan]
# 6    [Sam Worthington, Zoe Saldana, Sigourney Weaver]      [James Cameron]
# 11     [Robert Downey Jr., Chris Evans, Mark Ruffalo]        [Joss Whedon]

# %%
movies['overview'] = movies['overview'].apply(lambda x: x.split()) #convert lists
movies['tagline'] = movies['tagline'].apply(lambda x: x.split())


for col in ['cast', 'crew']:
    movies[col] = movies[col].apply(lambda x: [i.replace(" ", "") for i in x])  #space

movies["tags"] = (
    movies["overview"] 
    + movies["tagline"] 
    + movies["genres"] 
    + movies["keywords"] 
    + movies["cast"] 
    + movies["crew"]
)


movies['tags'] = movies['tags'].apply(lambda x: ' '.join(x).lower())


new_df = movies[['id', 'title', 'tags']]

# %%
movies.head(10)
# Out:
#         id                    title  \
# 0    27205                Inception
# 3   157336             Interstellar
# 4      155          The Dark Knight
# 6    19995                   Avatar
# 11   24428             The Avengers
# 14  293660                 Deadpool
# 15     550               Fight Club
# 19  118340  Guardians of the Galaxy
# 20     680             Pulp Fiction
# 21      13             Forrest Gump
#
#                                              overview  \
# 0   [Cobb,, a, skilled, thief, who, commits, corpo...
# 3   [The, adventures, of, a, group, of, explorers,...
# 4   [Batman, raises, the, stakes, in, his, war, on...
# 6   [In, the, 22nd, century,, a, paraplegic, Marin...
# 11  [When, an, unexpected, enemy, emerges, and, th...
# 14  [The, origin, story, of, former, Special, Forc...
# 15  [A, ticking-time-bomb, insomniac, and, a, slip...
# 19  [Light, years, from, Earth,, 26, years, after,...
# 20  [A, burger-loving, hit, man,, his, philosophic...
# 21  [A, man, with, a, low, IQ, has, accomplished, ...
#
#                                            genres  \
# 0            [Action, Science Fiction, Adventure]
# 3             [Adventure, Drama, Science Fiction]
# 4                [Drama, Action, Crime, Thriller]
# 6   [Action, Adventure, Fantasy, Science Fiction]
# 11           [Science Fiction, Action, Adventure]
# 14                    [Action, Adventure, Comedy]
# 15                                        [Drama]
# 19           [Action, Science Fiction, Adventure]
# 20                              [Thriller, Crime]
# 21                       [Comedy, Drama, Romance]
#
#                                              keywords  \
# 0   [rescue, mission, dream, airplane, paris, fran...
# 3   [rescue, future, spacecraft, race against time...
# 4   [joker, sadism, chaos, secret identity, crime ...
# 6   [future, society, culture clash, space travel,...
# 11  [new york city, superhero, shield, based on co...
# 14  [superhero, anti hero, mercenary, based on com...
# 15  [dual identity, rage and hate, based on novel ...
# 19  [spacecraft, based on comic, space, orphan, ad...
# 20  [drug dealer, boxer, massage, stolen money, br...
# 21  [vietnam war, vietnam veteran, mentally disabl...
#
#                                               tagline  \
# 0       [Your, mind, is, the, scene, of, the, crime.]
# 3   [Mankind, was, born, on, Earth., It, was, neve...
# 4            [Welcome, to, a, world, without, rules.]
# 6                   [Enter, the, world, of, Pandora.]
# 11                        [Some, assembly, required.]
# 14   [Witness, the, beginning, of, a, happy, ending.]
# 15                        [Mischief., Mayhem., Soap.]
# 19                   [All, heroes, start, somewhere.]
# 20  [Just, because, you, are, a, character, doesn'...
# 21  [The, world, will, never, be, the, same, once,...
#
#                                                  cast                crew  \
# 0   [LeonardoDiCaprio, JosephGordon-Levitt, EllenP...  [ChristopherNolan]
# 3   [MatthewMcConaughey, JessicaChastain, AnneHath...  [ChristopherNolan]
# 4          [ChristianBale, HeathLedger, AaronEckhart]  [ChristopherNolan]
# 6       [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 11         [RobertDowneyJr., ChrisEvans, MarkRuffalo]        [JossWhedon]
# 14           [RyanReynolds, MorenaBaccarin, EdSkrein]         [TimMiller]
# 15                 [EdwardNorton, BradPitt, MeatLoaf]      [DavidFincher]
# 19             [ChrisPratt, ZoeSaldana, DaveBautista]         [JamesGunn]
# 20        [JohnTravolta, SamuelL.Jackson, UmaThurman]  [QuentinTarantino]
# 21                [TomHanks, RobinWright, GarySinise]    [RobertZemeckis]
#
#                                                  tags
# 0   cobb, a skilled thief who commits corporate es...
# 3   the adventures of a group of explorers who mak...
# 4   batman raises the stakes in his war on crime. ...
# 6   in the 22nd century, a paraplegic marine is di...
# 11  when an unexpected enemy emerges and threatens...
# 14  the origin story of former special forces oper...
# 15  a ticking-time-bomb insomniac and a slippery s...
# 19  light years from earth, 26 years after being a...
# 20  a burger-loving hit man, his philosophical par...
# 21  a man with a low iq has accomplished great thi...

# %%
new_df.head(10)
# Out:
#         id                    title  \
# 0    27205                Inception
# 3   157336             Interstellar
# 4      155          The Dark Knight
# 6    19995                   Avatar
# 11   24428             The Avengers
# 14  293660                 Deadpool
# 15     550               Fight Club
# 19  118340  Guardians of the Galaxy
# 20     680             Pulp Fiction
# 21      13             Forrest Gump
#
#                                                  tags
# 0   cobb, a skilled thief who commits corporate es...
# 3   the adventures of a group of explorers who mak...
# 4   batman raises the stakes in his war on crime. ...
# 6   in the 22nd century, a paraplegic marine is di...
# 11  when an unexpected enemy emerges and threatens...
# 14  the origin story of former special forces oper...
# 15  a ticking-time-bomb insomniac and a slippery s...
# 19  light years from earth, 26 years after being a...
# 20  a burger-loving hit man, his philosophical par...
# 21  a man with a low iq has accomplished great thi...

# %%
new_df.head(1)
# Out:
#       id      title                                               tags
# 0  27205  Inception  cobb, a skilled thief who commits corporate es...

# %%
cv = CountVectorizer(max_features=1000000, stop_words='english')   # Vectorization
vectors = cv.fit_transform(new_df['tags']).toarray()               #matrix convert

# %%
similarity = cosine_similarity(vectors)   # Similarity matrix  #angle

# %%
def recommend(movie):
    movie = movie.strip()
    if movie not in new_df['title'].values:
        return []

    movie_index = new_df[new_df['title'] == movie].index[0]
    distances = list(enumerate(similarity[movie_index]))
    recommended = sorted(distances, key=lambda x: x[1], reverse=True)[1:6]
    return [new_df.iloc[i[0]].title for i in recommended]

# %%
    print(f"\nTop 5 movies similar to ")
    
        
#Inception ,Interstellar ,The Avengers , Iron Man


        
    recommendations = recommend("Iron Man")   



    print(recommendations)
# Out:
# Top 5 movies similar to
# ['Iron Man', 'Iron Man 2', 'Captain America: Civil War', 'Avengers: Age of Ultron', 'The Avengers']

# %%
# Save files
pickle.dump(new_df.to_dict(), open('movies_dict.pkl', 'wb'))
pickle.dump(similarity, open('similarity.pkl', 'wb'))
